# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import matplotlib.tri as tri
import matplotlib.axes as ax
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
import pyemma.plots as pymplt

# %%
name = "graph17_fes1-2.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/cp2k/4_hydrolysis_anneal/6_metadynamics/"

# %%
name = "fes_irene.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/CPMD/"

# %%
name = "fes_809.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/CPMD/6_hydrolysis_pseudo/6_5_metadynamics/"

# %%
name = "fes_809_noblanklines1.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/CPMD/6_hydrolysis_pseudo/6_5_metadynamics/"

# %%
name = "graph140_fes1-2.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/cp2k/4_hydrolysis_anneal/7_metadynamics/"

# %%
name = "fes_1349_1-2.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/CPMD/6_hydrolysis_pseudo/6_5_metadynamics/MEPSAnd/"

# %%
name = "fes_1483_1-2.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/CPMD/6_hydrolysis_pseudo/6_5_metadynamics/MEPSAnd/"

# %%
name = "fes_1586_1-2.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/CPMD/6_hydrolysis_pseudo/6_5_metadynamics/"

# %%
name = "fes_1097_1-2.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/CPMD/6_hydrolysis_pseudo/6_5b_metadynamics/"

# %%
name = "fes_535_1-2.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/CPMD/6_hydrolysis_pseudo/6_5_metadynamics/"

# %%
name = "graph223_fes1-2.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/cp2k/4_hydrolysis_anneal/7b_metadynamics/"

# %%
name = "graph372_fes1-2.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/cp2k/4_hydrolysis_anneal/7b_metadynamics/"

# %%
name = "fes.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/cp2k/4_hydrolysis_anneal/7b_metadynamics/350_meta/"

# %%
name = "fes_1914_1-2.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/CPMD/6_hydrolysis_pseudo/6_5b_metadynamics/"

# %%
name = "graph77_fes1-2.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/cp2k/4_hydrolysis_anneal/10_metadynamics/"

# %%
name = "fes_2133_1-2.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/CPMD/6_hydrolysis_pseudo/6_5b_metadynamics/"

# %%
name = "graph35_fes1-2.dat"
folder= "/home/oriol/Oriol/GH_A/GH79/cp2k/4_hydrolysis_anneal/11_metadynamics/"

# %%
data = np.loadtxt(folder+name)

# %%
np.arange(-5, 5, 0.25).size
# Out:
# 40

# %%
ax = fig.gca(projection='3d')
# surf = ax.plot_surface(data[:,0], data[:,1], data[:,2], cmap=cm.coolwarm, linewidth=0, antialiased=False)
surf = ax.scatter(data[:,0], data[:,1], data[:,2], cmap=cm.plasma)
plt.show()

# %%
# %matplotlib inline

fig = plt.figure(figsize=(10,8))
ax = fig.gca(projection='3d')
X = data[:,0]
Y = data[:,1]
Z = data[:,2]


# surf = ax.plot_surface(data[:,0], data[:,1], data[:,2], cmap=cm.coolwarm, linewidth=0, antialiased=False)
# ax.plot_wireframe(data[:,0], data[:,1], data[:,2], rstride=10, cstride=10)
# surf = ax.scatter(data[:,0], data[:,1], data[:,2], cmap=cm.plasma)
surf = ax.plot_trisurf(X, Y, Z,cmap=cm.CMRmap)
# ax.contourf(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
                
# ax.set_zlim(-1.01, 1.01)
# ax.zaxis.set_major_locator(LinearLocator(10))
# ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))


fig.colorbar(surf, shrink=0.7, aspect=5)
ax.view_init(0,270)


plt.tight_layout()
plt.show()

# %%
np.column_stack?
# Out:
# Signature: np.column_stack(tup)
# Docstring:
# Stack 1-D arrays as columns into a 2-D array.
#
# Take a sequence of 1-D arrays and stack them as columns
# to make a single 2-D array. 2-D arrays are stacked as-is,
# just like with `hstack`.  1-D arrays are turned into 2-D columns
# first.
#
# Parameters
# ----------
# tup : sequence of 1-D or 2-D arrays.
#     Arrays to stack. All of them must have the same first dimension.
#
# Returns
# -------
# stacked : 2-D array
#     The array formed by stacking the given arrays.
#
# See Also
# --------
# stack, hstack, vstack, concatenate
#
# Examples
# --------
# >>> a = np.array((1,2,3))
# >>> b = np.array((2,3,4))
# >>> np.column_stack((a,b))
# array([[1, 2],
#        [2, 3],
#        [3, 4]])
# File:      ~/miniconda3/envs/py3/lib/python3.6/site-packages/numpy/lib/shape_base.py
# Type:      function

# %%
data[np.argmin(data[:,2]),:]
# Out:
# array([  3.40973058,   1.4195545 , -27.24562128])

# %%
spath = np.loadtxt("/home/oriol/Oriol/GH_A/GH79/CPMD/6_hydrolysis_pseudo/6_5b_metadynamics/MEPSAnd/2133_1-2.spath")

# %%
spath = np.loadtxt("/home/oriol/Oriol/GH_A/GH79/cp2k/4_hydrolysis_anneal/7b_metadynamics/MEPSAnd/223_simp_0.spath")

# %%
spath = np.loadtxt("/home/oriol/Oriol/GH_A/GH79/CPMD/6_hydrolysis_pseudo/6_5b_metadynamics/MEPSAnd/1097_path_0.spath")

# %%
spath0 = np.loadtxt("/home/oriol/Oriol/GH_A/GH79/CPMD/6_hydrolysis_pseudo/6_5b_metadynamics/MEPSAnd/1097_path_0.spath")
spath1 = np.loadtxt("/home/oriol/Oriol/GH_A/GH79/CPMD/6_hydrolysis_pseudo/6_5b_metadynamics/MEPSAnd/1097_path_1.spath")
spath2 = np.loadtxt("/home/oriol/Oriol/GH_A/GH79/CPMD/6_hydrolysis_pseudo/6_5b_metadynamics/MEPSAnd/1097_path_2.spath")

# %%
#Reset data
x = data[:,0]
y = data[:,1]
z = data[:,2]

# %%
#For CP2K. From a.u. to Å and Kcal/mol
x = data[:,0]*0.5291772
y = data[:,1]*0.5291772
z = data[:,2]*627.50947

# %%
#For CP2K(mep). From a.u. to Å and Kcal/mol
x_path = spath[:,1]*0.5291772
y_path = spath[:,2]*0.5291772
e_path = spath[:,4]*627.50947
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-3bab906bbc0a> in <module>
#       1 #For CP2K(mep). From a.u. to Å and Kcal/mol
# ----> 2 x_path = spath[:,1]*0.5291772
#       3 y_path = spath[:,2]*0.5291772
#       4 e_path = spath[:,4]*627.50947
#
# NameError: name 'spath' is not defined

# %%
#For CPMD
x = data[:,0]
y = data[:,1]
z = data[:,2]

# %%
#For CPMD
x_path = spath[:,1]
y_path = spath[:,2]
e_path = spath[:,3]

# %%
min_path = np.amin(e_path)
max_path = np.amax(e_path)
print(min_path, max_path, min_path-max_path)
# Out:
# -33.336192625 -5.007361523 -28.328831102000002

# %%
n_levels = 30

fig, ax1 = plt.subplots(nrows=1)
# plt.figure(figsize=(12,16))
# fig.figsize = ([12,16])
fig.set_size_inches(12,8)

ax1.tricontour(x, y, z, levels=n_levels, linewidths=0.5, colors='k')
cntr = ax1.tricontourf(x, y, z, levels=n_levels, cmap="RdBu_r")

ax1.tick_params(labelsize=14)
cbar = fig.colorbar(cntr, ax=ax1)
# cbar.set_ticks(range(-2,-31,-2))
cbar.ax.tick_params(labelsize=14)
# cbar.ax.set_ylabel("Kcal/mol", rotation=270, fontsize=16)



name1 = name[0:3]+name[4:-4]
# ax1.set_title("{}".format(name1))
# ax1.set_title("FES CPMD-1097", fontsize=20)
plt.xlabel("CV1(C1-O(nucl))[Å]", fontsize=16)
plt.ylabel("CV2(C1-O(H2O))[Å]", fontsize=16)
# ax1.axis((1, 4.0, 0.95, 4.3))
# ax1.set_xticks(np.arange(2, 8, 0.2))
# ax1.set_yticks(np.arange(1.9, 8, 0.3))
ax1.grid(True)

# plt.plot(x_path,y_path,color='yellow' )
# plt.plot(spath[:,1],spath[:,2],color='yellow' )
# plt.plot(spath2[:,1],spath2[:,2])#,color='yellow' )

# plt.savefig("CP2K_350.png")
# plt.savefig("CPMD_2133.png")
# plt.savefig("{}.png".format(name1))

plt.show()
