# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Dades de prod3 del frame 0 al 2592

# %%
#O(nuc)-H2
file = open("/home/oriol/Oriol/GH_A/27_restraint21/canvi_conformacio.dat", 'r')
data1 = np.loadtxt(file)

# %%
#O(nuc)-O2
file = open("/home/oriol/Oriol/GH_A/27_restraint21/canvi_conformacio2.dat", 'r')
data2 = np.loadtxt(file)

# %%
#C(E45)-O2
file = open("/home/oriol/Oriol/GH_A/27_restraint21/canvi_conformacio3.dat", 'r')
data3 = np.loadtxt(file)

# %%
#Angle O(nuc)-O2-C(E45)
file = open("/home/oriol/Oriol/GH_A/27_restraint21/canvi_conformacio4.dat", 'r')
data4 = np.loadtxt(file)
mod_data4 = data1[:,0]*20/1000+368.2

# %% [markdown]
# 54ns amb restraint

# %%
# mod_data1 = data1[:,0]*20/1000+368.2
# mod_data2 = data2[:,0]*20/1000+368.2
# mod_data3 = data3[:,0]*20/1000+368.2

mod_data1 = data1[:,0]*20/1000+314
mod_data2 = data2[:,0]*20/1000+314
mod_data3 = data3[:,0]*20/1000+314

# %%
plt.figure(figsize=[14.0,6.0])
plt.plot(mod_data1,data1[:,1],linewidth=0.5, label="O(nuc)-H2")
plt.plot(mod_data2,data2[:,1],linewidth=0.5, label="O(nuc)-O2")
plt.plot(mod_data3,data3[:,1],linewidth=0.5, label="C(E45)-O2")

plt.xlabel("Time (ns)", fontsize=20)
plt.ylabel("Distance (Å)", fontsize=20)
plt.title("Conformation change",fontsize=24)
plt.legend(fontsize=16)
plt.yticks(fontsize=16)
plt.xticks(np.arange(315,370,5),fontsize=16)
plt.savefig("Conformation_change_dist.png")
plt.show()

# %%
plt.figure(figsize=[14.0,6.0])
plt.plot(mod_data1,data4[:,1],linewidth=0.5, label="O(nuc)-O2-C(E45)")
# plt.plot(mod_data2,data2[:,1],linewidth=0.5, label="O(nuc)-O2")
# plt.plot(mod_data3,data3[:,1],linewidth=0.5, label="C(E45)-O2")

plt.xlabel("Time (ns)", fontsize=20)
plt.ylabel("Angle(degree)", fontsize=20)
plt.title("Conformation change",fontsize=24)
plt.legend(fontsize=16)
plt.yticks(fontsize=16)
plt.xticks(np.arange(315,370,5),fontsize=16)
plt.savefig("Conformation_change_angle.png")
plt.show()

# %%
plt.figure(figsize=[14.0,6.0])
plt.plot(mod_data1,data4[:,1],linewidth=0.5, label="O(nuc)-O2-C(E45)")
# plt.plot(mod_data2,data2[:,1],linewidth=0.5, label="O(nuc)-O2")
# plt.plot(mod_data3,data3[:,1],linewidth=0.5, label="C(E45)-O2")
plt.xlabel("Time(ns)")
plt.ylabel("Angle(degree)")
plt.legend()
plt.show()
